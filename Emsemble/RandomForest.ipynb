# %%
from sklearn.ensemble import VotingClassifier, VotingRegressor, BaggingClassifier
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, KFold, RandomizedSearchCV 
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, plot_tree

from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, roc_auc_score, r2_score
from sklearn.linear_model import LogisticRegression, LinearRegression, ElasticNet
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVC
from ISLP import load_data
from sklearn.ensemble import RandomForestClassifier
import warnings

# %%
cancer = pd.read_csv("C:\\Users\\DAI.STUDENTSDC\\Desktop\\Machine_Learning\\Cases\\Wisconsin\\BreastCancer.csv")
X = cancer.drop('Class', axis = 1)
y = cancer.Class
X_test, X_train, y_test, y_train = train_test_split(X, y, random_state = 24, test_size = .3, stratify = y)

# %%
rf = RandomForestClassifier(random_state = 24)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9611451942740287

# %%
y_pred_proba = rf.predict_proba(X_test)[:, 1]
roc_auc_score(y_test,  y_pred_proba)
# Out:
# 0.9915033284023669

# %%
### on glass identification dataset

# %%
glass = pd.read_csv("C:\\Users\\DAI.STUDENTSDC\\Desktop\\Machine_Learning\\Cases\\Glass Identification\\Glass.csv")
y = glass.Type
X = glass.drop('Type', axis = 1)

# %%
params={'max_features':[3,4,5], 'n_estimators': [10,50,100]}
gcv= GridSearchCV(rf,param_grid= params, verbose=2 , cv= StratifiedKFold(n_splits=5, shuffle=True, random_state=24))
gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END ....................max_features=3, n_estimators=10; total time=   0.0s
# [CV] END ....................max_features=3, n_estimators=10; total time=   0.0s
# [CV] END ....................max_features=3, n_estimators=10; total time=   0.0s
# [CV] END ....................max_features=3, n_estimators=10; total time=   0.0s
# [CV] END ....................max_features=3, n_estimators=10; total time=   0.0s
# [CV] END ....................max_features=3, n_estimators=50; total time=   0.0s
# [CV] END ....................max_features=3, n_estimators=50; total time=   0.0s
# [CV] END ....................max_features=3, n_estimators=50; total time=   0.0s
# [CV] END ....................max_features=3, n_estimators=50; total time=   0.0s
# [CV] END ....................max_features=3, n_estimators=50; total time=   0.0s
# [CV] END ...................max_features=3, n_estimators=100; total time=   0.1s
# ...

# %%
print(gcv.best_params_, gcv.best_score_,sep='\n')
# Out:
# {'max_features': 3, 'n_estimators': 100}
# 0.8179401993355482

# %%
from sklearn.datasets import fetch_california_housing

# %%
a = fetch_california_housing
X, y = fetch_california_housing(as_frame = True, return_X_y = True)

# %%
X.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
housing = fetch_california_housing()

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor()
params = {'max_features':[3, 4, 5], 'n_estimators': [50, 100, 150], 'max_depth' : [None, 10, 8, 15]}
gcv = GridSearchCV(rfr, param_grid = params, cv = KFold(n_splits = 5, shuffle = True, random_state = 24),scoring = 'r2', verbose = 3)

# %%
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END max_depth=None, max_features=3, n_estimators=50;, score=0.821 total time=   4.3s
# [CV 2/5] END max_depth=None, max_features=3, n_estimators=50;, score=0.807 total time=   3.8s
# [CV 3/5] END max_depth=None, max_features=3, n_estimators=50;, score=0.824 total time=   3.7s
# [CV 4/5] END max_depth=None, max_features=3, n_estimators=50;, score=0.821 total time=   3.9s
# [CV 5/5] END max_depth=None, max_features=3, n_estimators=50;, score=0.821 total time=   4.0s
# [CV 1/5] END max_depth=None, max_features=3, n_estimators=100;, score=0.821 total time=   7.4s
# [CV 2/5] END max_depth=None, max_features=3, n_estimators=100;, score=0.806 total time=   7.8s
# [CV 3/5] END max_depth=None, max_features=3, n_estimators=100;, score=0.823 total time=   7.6s
# [CV 4/5] END max_depth=None, max_features=3, n_estimators=100;, score=0.827 total time=   7.9s
# ...

# %% [markdown]
# ### we use `RandomizedSearchCV` for it as it is designed for random forest and copes well with it instead of gridsearchcv

# %%
rfv = RandomizedSearchCV(rfr, param_distributions = params, n_iter = 15,  cv = KFold(n_splits = 5, shuffle = True, random_state = 24),scoring = 'r2', verbose = 3)

# %%
rfv.fit(X, y)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END max_depth=10, max_features=5, n_estimators=100;, score=0.790 total time=   6.6s
# [CV 2/5] END max_depth=10, max_features=5, n_estimators=100;, score=0.768 total time=   6.5s
# [CV 3/5] END max_depth=10, max_features=5, n_estimators=100;, score=0.788 total time=   6.8s
# [CV 4/5] END max_depth=10, max_features=5, n_estimators=100;, score=0.789 total time=   6.8s
# [CV 5/5] END max_depth=10, max_features=5, n_estimators=100;, score=0.786 total time=   7.1s
# [CV 1/5] END max_depth=15, max_features=3, n_estimators=150;, score=0.817 total time=   9.8s
# [CV 2/5] END max_depth=15, max_features=3, n_estimators=150;, score=0.804 total time=   9.7s
# [CV 3/5] END max_depth=15, max_features=3, n_estimators=150;, score=0.820 total time=   9.6s
# [CV 4/5] END max_depth=15, max_features=3, n_estimators=150;, score=0.821 total time=   8.8s
# ...

# %%
print(rfv.best_params_, rfv.best_score_, sep = '\n')
# Out:
# {'n_estimators': 150, 'max_features': 3, 'max_depth': None}
# 0.8214226865640081

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\DAI.STUDENTSDC\AppData\Local\anaconda3\python.exe

# %%
rfr = RandomForestRegressor(oob_score = True)

# %%
params = {'max_features':[3, 4], 'n_estimators': [50, 100], 'max_depth' : [None, 8, 15]}
rfv = RandomizedSearchCV(rfr, param_distributions = params, n_iter = 3, cv = KFold(n_splits = 5, shuffle = True, random_state = 24),scoring = 'r2', verbose = 3)

# %%
rfv.fit(X, y)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END max_depth=None, max_features=4, n_estimators=50;, score=0.814 total time=   5.1s
# [CV 2/5] END max_depth=None, max_features=4, n_estimators=50;, score=0.802 total time=   5.2s
# [CV 3/5] END max_depth=None, max_features=4, n_estimators=50;, score=0.816 total time=   5.2s
# [CV 4/5] END max_depth=None, max_features=4, n_estimators=50;, score=0.818 total time=   5.3s
# [CV 5/5] END max_depth=None, max_features=4, n_estimators=50;, score=0.819 total time=   5.5s
# [CV 1/5] END max_depth=15, max_features=3, n_estimators=100;, score=0.816 total time=   6.7s
# [CV 2/5] END max_depth=15, max_features=3, n_estimators=100;, score=0.800 total time=   5.9s
# [CV 3/5] END max_depth=15, max_features=3, n_estimators=100;, score=0.819 total time=   6.7s
# [CV 4/5] END max_depth=15, max_features=3, n_estimators=100;, score=0.820 total time=   6.4s
# ...

# %%
best = rfv.best_estimator_

# %% [markdown]
# ### `oob_score` by default is False we ave to set it to true to get the oob_score
# - it is computationally less expensive so that's why it is used in some cases
# - by default oob score is **`r2score`** for regression and **`accuracy_score`**

# %%
best.oob_score_
# Out:
# 0.8165394727422783

# %%
best.oob_prediction_
# Out:
# array([4.34011318, 4.13653289, 4.29754052, ..., 0.78702907, 0.88283517,
#        0.96305362])
